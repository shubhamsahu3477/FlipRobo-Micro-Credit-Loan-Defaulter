# %% [markdown]
# # Micro Credit Defaulter Project

# %% [markdown]
# ### Introduction:
# A Microfinance Institution (MFI) is an organization that offers financial services to low income populations. MFS becomes very useful when targeting especially the unbanked poor families living in remote areas with not much sources of income. The Microfinance services (MFS) provided by MFI are Group Loans, Agricultural Loans, Individual Business Loans and so on.

# %% [markdown]
# Many microfinance institutions (MFI), experts and donors are supporting the idea of using mobile financial services (MFS) which they feel are more convenient and efficient, and cost saving, than the traditional high-touch model used since long for the purpose of delivering microfinance services.
#
# Though, the MFI industry is primarily focusing on low income families and are very useful in such areas, the implementation of MFS has been uneven with both significant challenges and successes.
# Today, microfinance is widely accepted as a poverty-reduction tool, representing $70 billion in outstanding loans and a global outreach of 200 million clients.
#
# We are working with one such client that is in Telecom Industry. They are a fixed wireless telecommunications network provider. They have launched various products and have developed its business and organization based on the budget operator model, offering better products at Lower Prices to all value conscious customers through a strategy of disruptive innovation that focuses on the subscriber.
#
# They understand the importance of communication and how it affects a person’s life, thus, focusing on providing their services and products to low income families and poor customers that can help them in the need of hour.

# %% [markdown]
# ### Problem Statement :
# This project includes the real time problem for Micro Finance Institution (MFI) who offers financial services to lower income populations. MFI provides Micro Credit Loan on their mobile balance whihc needs to be paid back in 5 days.
#
# The Consumer is believed to be defaulter if he do not pay back the loaned amount within the time duration i.e. 5 days. For the loan amount of 5 (in Indonesian Rupiah), payback amount should be 6 (in Indonesian Rupiah), while, for the loan amount of 10 (in Indonesian Rupiah), the payback amount should be 12 (in Indonesian Rupiah).

# %% [markdown]
# ### Data :
#
# The dataset was provided by the client

# %%
# Let's load the necessary libraries

# Data Analysis and Data Wrangling
import pandas as pd
import numpy as np

# Data Visualization
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# Suppress warnings for a clean notebook
import warnings
warnings.filterwarnings('ignore')

# Print all librarires are loaded sucessfully
print('All Libraries are loaded sucessfully')
# Out:
# All Libraries are loaded sucessfully

# %%
# Let's load the Micro Credit Defaulter Data Set

credit=pd.read_csv('E:/Data Trained/Internship/Project/Project - 1/Micro Credit Project/Data file.csv')
print('Micro Credit Defaulter Data Set Loaded Sucessfully')
# Out:
# Micro Credit Defaulter Data Set Loaded Sucessfully

# %%
# Let's check the Data Set

credit.head()
# Out:
#    Unnamed: 0  label       msisdn    aon  daily_decr30  daily_decr90  \
# 0           1      0  21408I70789  272.0   3055.050000   3065.150000
# 1           2      1  76462I70374  712.0  12122.000000  12124.750000
# 2           3      1  17943I70372  535.0   1398.000000   1398.000000
# 3           4      1  55773I70781  241.0     21.228000     21.228000
# 4           5      1  03813I82730  947.0    150.619333    150.619333
#
#    rental30  rental90  last_rech_date_ma  last_rech_date_da  ...  \
# 0    220.13    260.13                2.0                0.0  ...
# 1   3691.26   3691.26               20.0                0.0  ...
# 2    900.13    900.13                3.0                0.0  ...
# 3    159.42    159.42               41.0                0.0  ...
# 4   1098.90   1098.90                4.0                0.0  ...
#
#    maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# 0              6.0                 0.0          2.0            12
# 1             12.0                 0.0          1.0            12
# 2              6.0                 0.0          1.0             6
# 3              6.0                 0.0          2.0            12
# 4              6.0                 0.0          7.0            42
#
#    maxamnt_loans90  medianamnt_loans90  payback30  payback90  pcircle  \
# 0                6                 0.0  29.000000  29.000000      UPW
# 1               12                 0.0   0.000000   0.000000      UPW
# 2                6                 0.0   0.000000   0.000000      UPW
# 3                6                 0.0   0.000000   0.000000      UPW
# 4                6                 0.0   2.333333   2.333333      UPW
#
#         pdate
# 0  2016-07-20
# 1  2016-08-10
# 2  2016-08-19
# 3  2016-06-06
# 4  2016-06-22
#
# [5 rows x 37 columns]

# %% [markdown]
# From the above table we can observe that "Unnamed:0" column is just the sl no column. So, we can drop this column.

# %% [markdown]
# ## Label Description
#
# **label:** Flag indicating whether the user paid back the credit amount within 5 days of issuing the loan{1:success, 0:failure}
#
# **msisdn:** mobile number of user
#
# **aon:** age on cellular network in days
#
# **daily_decr30:** Daily amount spent from main account, averaged over last 30 days (in Indonesian Rupiah)
#
# **daily_decr90:** Daily amount spent from main account, averaged over last 90 days (in Indonesian Rupiah)
#
# **rental30:** Average main account balance over last 30 days
#
# **rental90:** Average main account balance over last 90 days
#
# **last_rech_date_ma:** Number of days till last recharge of main account
#
# **last_rech_date_da:** Number of days till last recharge of data account
#
# **last_rech_amt_ma:** Amount of last recharge of main account (in Indonesian Rupiah)
#
# **cnt_ma_rech30:** Number of times main account got recharged in last 30 days
#
# **fr_ma_rech30:** Frequency of main account recharged in last 30 days
#
# **sumamnt_ma_rech30:** Total amount of recharge in main account over last 30 days (in Indonesian Rupiah)
#
# **medianamnt_ma_rech30:** Median of amount of recharges done in main account over last 30 days at user level (in Indonesian Rupiah)
#
# **medianmarechprebal30:** Median of main account balance just before recharge in last 30 days at user level (in Indonesian Rupiah)
#
# **cnt_ma_rech90:** Number of times main account got recharged in last 90 days
#
# **fr_ma_rech90:** Frequency of main account recharged in last 90 days
#
# **sumamnt_ma_rech90:** Total amount of recharge in main account over last 90 days (in Indonasian Rupiah)
#
# **medianamnt_ma_rech90:** Median of amount of recharges done in main account over last 90 days at user level (in Indonasian Rupiah)
#
# **medianmarechprebal90:** Median of main account balance just before recharge in last 90 days at user level (in Indonasian Rupiah)
#
# **cnt_da_rech30:** Number of times data account got recharged in last 30 days
#
# **fr_da_rech30:** Frequency of data account recharged in last 30 days
#
# **cnt_da_rech90:** Number of times data account got recharged in last 90 days
#
# **fr_da_rech90:** Frequency of data account recharged in last 90 days
#
# **cnt_loans30:** Number of loans taken by user in last 30 days
#
# **amnt_loans30:** Total amount of loans taken by user in last 30 days
#
# **maxamnt_loans30:** maximum amount of loan taken by the user in last 30 days
#
# **medianamnt_loans30:** Median of amounts of loan taken by the user in last 30 days
#
# **cnt_loans90:** Number of loans taken by user in last 90 days
#
# **amnt_loans90:** Total amount of loans taken by user in last 90 days
#
# **maxamnt_loans90:** maximum amount of loan taken by the user in last 90 days
#
# **medianamnt_loans90:** Median of amounts of loan taken by the user in last 90 days
#
# **payback30:** Average payback time in days over last 30 days
#
# **payback90:** Average payback time in days over last 90 days
#
# **pcircle:** telecom circle
#
# **pdate:** date

# %%
# Let's drop the unnecessary column

credit.drop('Unnamed: 0',axis=1,inplace=True)

# %% [markdown]
# We are dropping the 'Unnamed: 0' column because it just the serial number/label column which is of no use to us

# %%
# Let's check the shape

credit.shape
# Out:
# (209593, 36)

# %% [markdown]
# We have 209593 rows and 36 columns in our dataset

# %%
# Let's check the columns names

credit.columns
# Out:
# Index(['label', 'msisdn', 'aon', 'daily_decr30', 'daily_decr90', 'rental30',
#        'rental90', 'last_rech_date_ma', 'last_rech_date_da',
#        'last_rech_amt_ma', 'cnt_ma_rech30', 'fr_ma_rech30',
#        'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30',
#        'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90',
#        'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30',
#        'fr_da_rech30', 'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30',
#        'amnt_loans30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90',
#        'amnt_loans90', 'maxamnt_loans90', 'medianamnt_loans90', 'payback30',
#        'payback90', 'pcircle', 'pdate'],
#       dtype='object')

# %%
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209593 entries, 0 to 209592
# Data columns (total 36 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   label                 209593 non-null  int64
#  1   msisdn                209593 non-null  object
#  2   aon                   209593 non-null  float64
#  3   daily_decr30          209593 non-null  float64
#  4   daily_decr90          209593 non-null  float64
#  5   rental30              209593 non-null  float64
#  6   rental90              209593 non-null  float64
#  7   last_rech_date_ma     209593 non-null  float64
#  8   last_rech_date_da     209593 non-null  float64
#  9   last_rech_amt_ma      209593 non-null  int64
#  10  cnt_ma_rech30         209593 non-null  int64
#  11  fr_ma_rech30          209593 non-null  float64
#  12  sumamnt_ma_rech30     209593 non-null  float64
#  13  medianamnt_ma_rech30  209593 non-null  float64
#  14  medianmarechprebal30  209593 non-null  float64
#  15  cnt_ma_rech90         209593 non-null  int64
#  16  fr_ma_rech90          209593 non-null  int64
#  17  sumamnt_ma_rech90     209593 non-null  int64
#  18  medianamnt_ma_rech90  209593 non-null  float64
#  19  medianmarechprebal90  209593 non-null  float64
#  20  cnt_da_rech30         209593 non-null  float64
#  21  fr_da_rech30          209593 non-null  float64
#  22  cnt_da_rech90         209593 non-null  int64
#  23  fr_da_rech90          209593 non-null  int64
#  24  cnt_loans30           209593 non-null  int64
#  25  amnt_loans30          209593 non-null  int64
#  26  maxamnt_loans30       209593 non-null  float64
#  27  medianamnt_loans30    209593 non-null  float64
#  28  cnt_loans90           209593 non-null  float64
#  29  amnt_loans90          209593 non-null  int64
#  30  maxamnt_loans90       209593 non-null  int64
#  31  medianamnt_loans90    209593 non-null  float64
#  32  payback30             209593 non-null  float64
#  33  payback90             209593 non-null  float64
#  34  pcircle               209593 non-null  object
#  35  pdate                 209593 non-null  object
# dtypes: float64(21), int64(12), object(3)
# memory usage: 57.6+ MB

# %% [markdown]
# We can observe from the above output that we have 3 types of dataypes in our dataset i.e. Int, object and float

# %%
#Let's check the statistic matrix

credit.describe()
# Out:
#                label            aon   daily_decr30   daily_decr90  \
# count  209593.000000  209593.000000  209593.000000  209593.000000
# mean        0.875177    8112.343445    5381.402289    6082.515068
# std         0.330519   75696.082531    9220.623400   10918.812767
# min         0.000000     -48.000000     -93.012667     -93.012667
# 25%         1.000000     246.000000      42.440000      42.692000
# 50%         1.000000     527.000000    1469.175667    1500.000000
# 75%         1.000000     982.000000    7244.000000    7802.790000
# max         1.000000  999860.755168  265926.000000  320630.000000
#
#             rental30       rental90  last_rech_date_ma  last_rech_date_da  \
# count  209593.000000  209593.000000      209593.000000      209593.000000
# mean     2692.581910    3483.406534        3755.847800        3712.202921
# std      4308.586781    5770.461279       53905.892230       53374.833430
# min    -23737.140000  -24720.580000         -29.000000         -29.000000
# 25%       280.420000     300.260000           1.000000           0.000000
# 50%      1083.570000    1334.000000           3.000000           0.000000
# 75%      3356.940000    4201.790000           7.000000           0.000000
# max    198926.110000  200148.110000      998650.377733      999171.809410
#
#        last_rech_amt_ma  cnt_ma_rech30  ...    cnt_loans30   amnt_loans30  \
# count     209593.000000  209593.000000  ...  209593.000000  209593.000000
# mean        2064.452797       3.978057  ...       2.758981      17.952021
# std         2370.786034       4.256090  ...       2.554502      17.379741
# min            0.000000       0.000000  ...       0.000000       0.000000
# 25%          770.000000       1.000000  ...       1.000000       6.000000
# 50%         1539.000000       3.000000  ...       2.000000      12.000000
# 75%         2309.000000       5.000000  ...       4.000000      24.000000
# max        55000.000000     203.000000  ...      50.000000     306.000000
#
#        maxamnt_loans30  medianamnt_loans30    cnt_loans90   amnt_loans90  \
# count    209593.000000       209593.000000  209593.000000  209593.000000
# mean        274.658747            0.054029      18.520919      23.645398
# std        4245.264648            0.218039     224.797423      26.469861
# min           0.000000            0.000000       0.000000       0.000000
# 25%           6.000000            0.000000       1.000000       6.000000
# 50%           6.000000            0.000000       2.000000      12.000000
# 75%           6.000000            0.000000       5.000000      30.000000
# max       99864.560864            3.000000    4997.517944     438.000000
#
#        maxamnt_loans90  medianamnt_loans90      payback30      payback90
# count    209593.000000       209593.000000  209593.000000  209593.000000
# mean          6.703134            0.046077       3.398826       4.321485
# std           2.103864            0.200692       8.813729      10.308108
# min           0.000000            0.000000       0.000000       0.000000
# 25%           6.000000            0.000000       0.000000       0.000000
# 50%           6.000000            0.000000       0.000000       1.666667
# 75%           6.000000            0.000000       3.750000       4.500000
# max          12.000000            3.000000     171.500000     171.500000
#
# [8 rows x 33 columns]

# %% [markdown]
# #### Observations:
#     1- We can observe that some of the dataset features are ordinal or binary, whereas other features are continous.
#
#     2- We can observe that some columns have negative values like rental30 and renatal90 given our data these values can be negative, wherer as some other columns like aon, daily_decr30, daily_decr90, last_rech_date_ma, last_rech_date_da these columns can not have negative values as these values do not make any sence in ourdataset.

# %%
# Let's check the negative values present in our dataset

(credit.drop(['pdate','pcircle','msisdn'],axis=1) >= 0).all()
# Out:
# label                    True
# aon                     False
# daily_decr30            False
# daily_decr90            False
# rental30                False
# rental90                False
# last_rech_date_ma       False
# last_rech_date_da       False
# last_rech_amt_ma         True
# cnt_ma_rech30            True
# fr_ma_rech30             True
# sumamnt_ma_rech30        True
# medianamnt_ma_rech30     True
# medianmarechprebal30    False
# cnt_ma_rech90            True
# fr_ma_rech90             True
# sumamnt_ma_rech90        True
# medianamnt_ma_rech90     True
# medianmarechprebal90    False
# cnt_da_rech30            True
# fr_da_rech30             True
# cnt_da_rech90            True
# fr_da_rech90             True
# cnt_loans30              True
# amnt_loans30             True
# maxamnt_loans30          True
# medianamnt_loans30       True
# cnt_loans90              True
# amnt_loans90             True
# maxamnt_loans90          True
# medianamnt_loans90       True
# payback30                True
# payback90                True
# dtype: bool

# %% [markdown]
# We can observe from the above output that 'aon', 'daily_decr30', 'daily_decr90', 'rental30', 'rental90', 'last_rech_date_ma', 'last_rech_date_da', 'medianmarechprebal30', 'medianmarechprebal90' columns have negative values in them.
#
# But as per the caolumn lable only 'rental30' & 'rental90' column negative value is justifiable rest negative values are outlier.
#
# So, we are going to drop those rows where we have negative values.

# %% [markdown]
# ## Data Pre-Processing

# %%
# We will now drop the 'rental30' & 'rental90' from our dataset so that those columns values will not be effected when we drop the negative value rows

credit.drop(['rental30', 'rental90', 'pcircle', 'pdate', 'msisdn'],axis=1, inplace=True)

# %%
# Let's remove the negative values rows from our dataset

# Code Reference link(https://www.xspcredit.com/resolution/54296999.html)

from nltk import flatten
index=[]
for cols in credit.columns.values:
    data1=credit[credit[f'{cols}'] < 0].index.values
    data2=data1.tolist()
    index.append(data2)
dataindex=flatten(index)

# %%
#Let's drop the negative values column in the our dataset beacause they they do not add value in our analysis

credit.drop(dataindex,inplace=True)

# %%
#Let's check of there are any negative values in the dataset

credit[70:80]
# Out:
#     label     aon  daily_decr30  daily_decr90  last_rech_date_ma  \
# 71      1  1589.0     22.521000     22.521000                4.0
# 72      1   138.0     67.679333     67.679333                6.0
# 73      1   660.0   1012.166667   1014.600000               19.0
# 75      1   677.0    107.063000    107.063000                5.0
# 76      0   621.0    600.000000    600.000000                0.0
# 77      1   383.0   1219.782000   1238.740000               22.0
# 79      1   318.0  21792.240000  21826.800000                2.0
# 80      1  1122.0   3391.000000   3567.070000               14.0
# 81      1   951.0   1888.532667   1914.940000                9.0
# 82      1    96.0     79.541667     79.541667                5.0
#
#     last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  fr_ma_rech30  \
# 71                0.0              2320              2           2.0
# 72                0.0              2309              3           7.0
# 73                0.0              1539              1           0.0
# 75                0.0              4048              2          27.0
# 76                0.0                 0              0           0.0
# 77                0.0              3178              1           0.0
# 79                0.0              3178              6           2.0
# 80                0.0               773              1           0.0
# 81                0.0               770              6           4.0
# 82                0.0              5787              3          11.0
#
#     sumamnt_ma_rech30  ...  cnt_loans30  amnt_loans30  maxamnt_loans30  \
# 71             4040.0  ...            2            12              6.0
# 72             5387.0  ...            2            12              6.0
# 73             1539.0  ...            1             6              6.0
# 75             5587.0  ...            3            18              6.0
# 76                0.0  ...            1             6              6.0
# 77             3178.0  ...            1             6              6.0
# 79            22547.0  ...            5            42             12.0
# 80              773.0  ...            1             6              6.0
# 81             5389.0  ...            2            12              6.0
# 82             9635.0  ...            2            12              6.0
#
#     medianamnt_loans30  cnt_loans90  amnt_loans90  maxamnt_loans90  \
# 71                 0.0          2.0            12                6
# 72                 0.0          2.0            12                6
# 73                 0.0          1.0             6                6
# 75                 0.0          3.0            18                6
# 76                 0.0          1.0             6                6
# 77                 0.0          1.0             6                6
# 79                 0.0          6.0            48               12
# 80                 0.0          1.0             6                6
# 81                 0.0          3.0            18                6
# 82                 0.0          2.0            12                6
#
#     medianamnt_loans90  payback30  payback90
# 71                 0.0        0.0        0.0
# 72                 0.0        0.0        0.0
# 73                 0.0        0.0        0.0
# 75                 0.0        2.5        2.5
# 76                 0.0        0.0        0.0
# 77                 0.0        0.0        0.0
# 79                 0.0        4.8        4.8
# 80                 0.0        0.0        0.0
# 81                 0.0        0.0        6.5
# 82                 0.0        0.0        0.0
#
# [10 rows x 31 columns]

# %% [markdown]
# We can observe from the above output that row number 74 & 78 is removed from the data which contains negative values.
#
# So we have successfully dropped the negative values row from our dataset

# %%
#Let's check the shape of our data set after we have dropped the unnecessary columns which have negative values

credit.shape
# Out:
# (203119, 31)

# %% [markdown]
# After dropping the negative values column we have now 203119 rows left in our dataset

# %%
#Let's check the percentage (%) of data set we have droped from our dataset while removing the negative values

(209593-203119)*100/209593
# Out:
# 3.0888436159604566

# %% [markdown]
# We can observe that we have removed around 3.088% of data from our dataset. Since our data is expensive so we have to be very carefule with the dataset because we can not loose more that 7 to 8% of data.
#
# Since, we have already removed around 3.1% of data so we have to be extra careful while treating the outlier that we should not further remove data more than 5%.

# %%
# Let's re-check the negative values present in our dataset

(credit >= 0).all()
# Out:
# label                   True
# aon                     True
# daily_decr30            True
# daily_decr90            True
# last_rech_date_ma       True
# last_rech_date_da       True
# last_rech_amt_ma        True
# cnt_ma_rech30           True
# fr_ma_rech30            True
# sumamnt_ma_rech30       True
# medianamnt_ma_rech30    True
# medianmarechprebal30    True
# cnt_ma_rech90           True
# fr_ma_rech90            True
# sumamnt_ma_rech90       True
# medianamnt_ma_rech90    True
# medianmarechprebal90    True
# cnt_da_rech30           True
# fr_da_rech30            True
# cnt_da_rech90           True
# fr_da_rech90            True
# cnt_loans30             True
# amnt_loans30            True
# maxamnt_loans30         True
# medianamnt_loans30      True
# cnt_loans90             True
# amnt_loans90            True
# maxamnt_loans90         True
# medianamnt_loans90      True
# payback30               True
# payback90               True
# dtype: bool

# %%
# Let's reload the data set and add the pdate, rental90 and rental30 vlues in our data set
#rental30 and rental90 column contains negative values which are very importnt in our analysis

micro_credit=pd.read_csv('E:/Data Trained/Internship/Project/Project - 1/Micro Credit Project/Data file.csv')
print('Micro Credit Defaulter Data Set Re-Loaded Sucessfully')
# Out:
# Micro Credit Defaulter Data Set Re-Loaded Sucessfully

# %%
credit['rental30']=micro_credit['rental30']
credit['rental90']=micro_credit['rental90']
credit['pdate']=micro_credit['pdate']

# %% [markdown]
# We are now again merging the removed features which are having negative values and are required for the analysis.

# %%
# Let's change the Date dtype to datetime series

credit['pdate']=pd.to_datetime(credit['pdate'])

# %%
# Lets split the year and month from the Date for better visulatization

credit['Year']=credit['pdate'].dt.year
credit['Month']=credit['pdate'].dt.month
credit.Month = credit.Month.map({1:'JAN',2:'FEB',3:'MAR',4:'APR',5:'MAY',6:'JUN',7:'JUL',8:'AUG',9:'SEPT',10:'OCT',11:'NOV',12:'DEC'})
credit['Day']=credit['pdate'].dt.day

# %%
# Let's drop the unnecessary column

credit.drop(['pdate','Year'],axis=1,inplace=True)

# %%
credit.head()
# Out:
#    label    aon  daily_decr30  daily_decr90  last_rech_date_ma  \
# 0      0  272.0   3055.050000   3065.150000                2.0
# 1      1  712.0  12122.000000  12124.750000               20.0
# 2      1  535.0   1398.000000   1398.000000                3.0
# 3      1  241.0     21.228000     21.228000               41.0
# 4      1  947.0    150.619333    150.619333                4.0
#
#    last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  fr_ma_rech30  \
# 0                0.0              1539              2          21.0
# 1                0.0              5787              1           0.0
# 2                0.0              1539              1           0.0
# 3                0.0               947              0           0.0
# 4                0.0              2309              7           2.0
#
#    sumamnt_ma_rech30  ...  cnt_loans90  amnt_loans90  maxamnt_loans90  \
# 0             3078.0  ...          2.0            12                6
# 1             5787.0  ...          1.0            12               12
# 2             1539.0  ...          1.0             6                6
# 3                0.0  ...          2.0            12                6
# 4            20029.0  ...          7.0            42                6
#
#    medianamnt_loans90  payback30  payback90  rental30  rental90  Month  Day
# 0                 0.0  29.000000  29.000000    220.13    260.13    JUL   20
# 1                 0.0   0.000000   0.000000   3691.26   3691.26    AUG   10
# 2                 0.0   0.000000   0.000000    900.13    900.13    AUG   19
# 3                 0.0   0.000000   0.000000    159.42    159.42    JUN    6
# 4                 0.0   2.333333   2.333333   1098.90   1098.90    JUN   22
#
# [5 rows x 35 columns]

# %%
#Let's check the value counts in each columns

for i in credit.columns:
    print(credit[i].value_counts())
    print('\n')
# Out:
# 1    179392
# 0     23727
# Name: label, dtype: int64
#
#
# 95.000000        384
# 92.000000        352
# 96.000000        351
# 99.000000        348
# 157.000000       344
#                 ...
# 674077.391275      1
# 727237.751125      1
# 551689.999760      1
# 565600.545960      1
# 654112.274642      1
# Name: aon, Length: 4407, dtype: int64
#
#
# 0.000000       4102
# 500.000000      819
# 1000.000000     564
# 700.000000      345
# 600.000000      344
#                ...
# 4249.653333       1
# 158.813667        1
# 50.869000         1
# 8471.565000       1
# 8.687000          1
# Name: daily_decr30, Length: 144077, dtype: int64
#
#
# 0.000000        4023
# 500.000000       771
# 1000.000000      485
# 700.000000       310
# 600.000000       307
#                 ...
# 64533.950000       1
# 126.193333         1
# 16218.460000       1
# 59.438333          1
# 67733.260000       1
# Name: daily_decr90, Length: 155570, dtype: int64
#
#
# 1.000000         45828
# 2.000000         26327
# 3.000000         19715
# 0.000000         19050
# 4.000000         15243
#                  ...
# 629873.415222        1
# 538864.053087        1
# 814873.667085        1
# 605918.724905        1
# 990442.339913        1
# Name: last_rech_date_ma, Length: 1136, dtype: int64
#
#
# 0.000000         196474
# 7.000000            160
# 8.000000            158
# 11.000000           147
# 13.000000           147
#                   ...
# 909781.190334         1
# 957019.803696         1
# 751559.916534         1
# 635922.630667         1
# 597168.240929         1
# Name: last_rech_date_da, Length: 1142, dtype: int64
#
#
# 1539     54999
# 770      40650
# 0        19294
# 773      18713
# 2309     15802
#          ...
# 19913        1
# 4066         1
# 14783        1
# 10454        1
# 22609        1
# Name: last_rech_amt_ma, Length: 69, dtype: int64
#
#
# 1      35215
# 2      30215
# 0      25978
# 3      24990
# 4      19973
#        ...
# 64         1
# 63         1
# 59         1
# 50         1
# 115        1
# Name: cnt_ma_rech30, Length: 71, dtype: int64
#
#
# 0.000000         74405
# 1.000000         22052
# 2.000000         18573
# 3.000000         14115
# 4.000000         11015
#                  ...
# 901689.878199        1
# 782050.438807        1
# 559942.648164        1
# 791337.927571        1
# 579792.661825        1
# Name: fr_ma_rech30, Length: 1056, dtype: int64
#
#
# 0.0        25978
# 1539.0      8499
# 770.0       5540
# 2309.0      4378
# 773.0       4122
#            ...
# 41661.0        1
# 28100.0        1
# 20828.0        1
# 18442.0        1
# 40559.0        1
# Name: sumamnt_ma_rech30, Length: 15073, dtype: int64
#
#
# 1539.0     46804
# 770.0      29900
# 0.0        25978
# 773.0      21911
# 2309.0     10985
#            ...
# 13695.5        1
# 5860.0         1
# 2793.0         1
# 3622.0         1
# 3295.5         1
# Name: medianamnt_ma_rech30, Length: 501, dtype: int64
#
#
# 0.00       28602
# 20.00       1095
# 19.00       1063
# 17.00       1042
# 10.00       1013
#            ...
# 254.78         1
# 43.80          1
# 2393.09        1
# 57.68          1
# 26.11          1
# Name: medianmarechprebal30, Length: 29138, dtype: int64
#
#
# 1      26067
# 2      23037
# 3      19873
# 0      19251
# 4      16950
#        ...
# 151        1
# 336        1
# 121        1
# 172        1
# 127        1
# Name: cnt_ma_rech90, Length: 110, dtype: int64
#
#
# 0     61897
# 1     24032
# 2     18999
# 3     13009
# 4      9860
#       ...
# 81        7
# 80        6
# 84        4
# 88        4
# 87        1
# Name: fr_ma_rech90, Length: 89, dtype: int64
#
#
# 0        19251
# 1539      5254
# 773       3771
# 770       3594
# 2309      2439
#          ...
# 11383        1
# 50472        1
# 46374        1
# 36129        1
# 64752        1
# Name: sumamnt_ma_rech90, Length: 31636, dtype: int64
#
#
# 1539.0     44899
# 773.0      29633
# 770.0      23138
# 0.0        19251
# 2309.0     10501
#            ...
# 4666.5         1
# 5750.0         1
# 5786.5         1
# 490.0          1
# 19913.0        1
# Name: medianamnt_ma_rech90, Length: 597, dtype: int64
#
#
# 0.00      21596
# 20.00      1251
# 19.00      1182
# 26.00      1158
# 27.00      1146
#           ...
# 832.47        1
# 255.77        1
# 36.78         1
# 73.94         1
# 114.34        1
# Name: medianmarechprebal90, Length: 28484, dtype: int64
#
#
# 0.000000        199084
# 1.000000          2280
# 2.000000           370
# 3.000000           155
# 4.000000            86
#                  ...
# 63823.301647         1
# 32152.874529         1
# 45934.211400         1
# 57073.740639         1
# 15321.247575         1
# Name: cnt_da_rech30, Length: 1042, dtype: int64
#
#
# 0.000000         201574
# 3.000000             63
# 1.000000             55
# 2.000000             51
# 7.000000             47
#                   ...
# 540679.626283         1
# 692783.146049         1
# 609355.763299         1
# 532065.305859         1
# 849620.029563         1
# Name: fr_da_rech30, Length: 1040, dtype: int64
#
#
# 0     197815
# 1       4116
# 2        554
# 3        225
# 4        149
# 5         74
# 6         49
# 7         36
# 8         30
# 9         18
# 14         9
# 12         7
# 11         7
# 10         6
# 13         6
# 16         4
# 18         3
# 15         2
# 30         1
# 17         1
# 19         1
# 20         1
# 22         1
# 25         1
# 27         1
# 28         1
# 38         1
# Name: cnt_da_rech90, dtype: int64
#
#
# 0     202258
# 3         76
# 1         66
# 2         66
# 4         56
# 7         55
# 6         52
# 5         45
# 8         43
# 14        32
# 10        32
# 9         32
# 11        30
# 12        27
# 19        22
# 28        19
# 13        17
# 15        17
# 18        16
# 29        15
# 16        14
# 17        14
# 22        11
# 25        11
# 21        10
# 20         9
# 24         8
# 27         8
# 32         8
# 26         7
# 30         7
# 31         6
# 34         5
# 23         5
# 37         5
# 57         3
# 35         2
# 41         2
# 46         1
# 56         1
# 55         1
# 33         1
# 43         1
# 42         1
# 39         1
# 64         1
# Name: fr_da_rech90, dtype: int64
#
#
# 1     78398
# 2     41975
# 3     26755
# 4     17348
# 5     11572
# 6      7718
# 7      5013
# 8      3357
# 0      3216
# 9      2261
# 10     1556
# 11     1131
# 12      789
# 13      545
# 14      382
# 15      269
# 16      213
# 17      162
# 18       98
# 19       77
# 20       53
# 21       45
# 22       42
# 23       38
# 25       19
# 26       17
# 27       15
# 24       13
# 29        9
# 31        8
# 28        7
# 30        4
# 32        4
# 33        3
# 38        2
# 41        1
# 44        1
# 36        1
# 35        1
# 50        1
# Name: cnt_loans30, dtype: int64
#
#
# 6      71644
# 12     43669
# 18     26076
# 24     18256
# 30     11894
# 36      8496
# 42      5549
# 48      3962
# 0       3216
# 54      2647
# 60      2028
# 66      1389
# 72      1098
# 78       735
# 84       577
# 90       393
# 96       333
# 102      251
# 108      182
# 114      135
# 120      117
# 132       91
# 126       80
# 138       64
# 156       34
# 144       30
# 150       30
# 162       29
# 168       20
# 174       17
# 186       15
# 180       13
# 192        7
# 198        6
# 210        4
# 252        4
# 228        4
# 216        4
# 276        3
# 222        3
# 264        3
# 258        3
# 204        2
# 240        2
# 300        1
# 270        1
# 306        1
# 246        1
# Name: amnt_loans30, dtype: int64
#
#
# 6.000000        172957
# 12.000000        25947
# 0.000000          3202
# 94938.650685         1
# 90919.615488         1
#                  ...
# 21935.072346         1
# 31162.008778         1
# 26462.333521         1
# 53666.885900         1
# 52729.827918         1
# Name: maxamnt_loans30, Length: 1016, dtype: int64
#
#
# 0.0    189313
# 1.0      6893
# 0.5      6452
# 2.0       420
# 1.5        38
# 3.0         3
# Name: medianamnt_loans30, dtype: int64
#
#
# 1.000000       68956
# 2.000000       36603
# 3.000000       23722
# 4.000000       16610
# 5.000000       12244
#                ...
# 2508.179038        1
# 2604.261985        1
# 2988.712262        1
# 4708.657723        1
# 4139.659956        1
# Name: cnt_loans90, Length: 1073, dtype: int64
#
#
# 6      64233
# 12     38225
# 18     23589
# 24     17053
# 30     12418
#        ...
# 360        1
# 426        1
# 396        1
# 438        1
# 342        1
# Name: amnt_loans90, Length: 69, dtype: int64
#
#
# 6     174665
# 12     26441
# 0       2013
# Name: maxamnt_loans90, dtype: int64
#
#
# 0.0    191287
# 1.0      5921
# 0.5      5582
# 2.0       307
# 1.5        19
# 3.0         3
# Name: medianamnt_loans90, dtype: int64
#
#
# 0.00      101350
# 2.00        5564
# 3.00        4967
# 4.00        3894
# 2.50        3477
#            ...
# 18.60          1
# 28.40          1
# 154.50         1
# 35.80          1
# 33.75          1
# Name: payback30, Length: 1356, dtype: int64
#
#
# 0.000000     90429
# 2.000000      4947
# 3.000000      4390
# 4.000000      3574
# 2.500000      2983
#              ...
# 33.400000        1
# 42.800000        1
# 11.928571        1
# 1.968750         1
# 10.277778        1
# Name: payback90, Length: 2369, dtype: int64
#
#
# 0.00        6689
# 200.13      1352
# 99.56        977
# 400.26       524
# 199.12       452
#             ...
# 46.50          1
# 12.75          1
# 33484.65       1
# 2791.33        1
# 316.17         1
# Name: rental30, Length: 129753, dtype: int64
# 0.00        6047
# 200.13       889
# 99.56        723
# 90.00        673
# 60.00        672
#             ...
# 2843.98        1
# 11628.18       1
# 1178.57        1
# 1693.43        1
# 7373.51        1
# Name: rental90, Length: 138467, dtype: int64
#
#
# JUL    84605
# JUN    78154
# AUG    40360
# Name: Month, dtype: int64
#
#
# 11    7833
# 12    7819
# 10    7814
# 13    7747
# 7     7717
# 6     7692
# 8     7635
# 15    7630
# 14    7614
# 5     7605
# 2     7602
# 1     7535
# 9     7461
# 17    7450
# 16    7387
# 3     7375
# 18    7116
# 4     6849
# 19    6726
# 20    6526
# 21    5791
# 23    5643
# 22    5592
# 27    5128
# 25    5117
# 26    5016
# 24    4949
# 29    4914
# 30    4913
# 28    4764
# 31    2159
# Name: Day, dtype: int64

# %%
#Let's check the % of defaulter and non defaluters customers

total_customers = credit.shape[0]
print("Total customers: {}".format(total_customers))
non_defaulter_customers = credit[credit["label"] == 1].shape[0]
print("Non defaulter customer: {}".format(non_defaulter_customers))
defaulter_customers = credit[credit["label"] == 0].shape[0]
print("Defaulter customer : {}".format(defaulter_customers))
non_defaulter_percent = (non_defaulter_customers/total_customers)*100
print("Non Defaulter Customer percentage : {0:.2f}%".format(non_defaulter_percent))
defaulter_percent = (defaulter_customers/total_customers)*100
print("Deafulter Customer : {0:.2f}%".format(defaulter_percent))
# Out:
# Total customers: 203119
# Non defaulter customer: 179392
# Defaulter customer : 23727
# Non Defaulter Customer percentage : 88.32%
# Deafulter Customer : 11.68%

# %% [markdown]
# We can observe that we have around 88.32% Non Defaulter and 11.68% Defaluter customers in our dataset and from the above result it is very clear that our data is imbalanced.1

# %% [markdown]
# ## Exploratory Data Anaysis

# %%
#Let's confirm that we do not have any null values in our dataset

credit.isnull().sum()
# Out:
# label                   0
# aon                     0
# daily_decr30            0
# daily_decr90            0
# last_rech_date_ma       0
# last_rech_date_da       0
# last_rech_amt_ma        0
# cnt_ma_rech30           0
# fr_ma_rech30            0
# sumamnt_ma_rech30       0
# medianamnt_ma_rech30    0
# medianmarechprebal30    0
# cnt_ma_rech90           0
# fr_ma_rech90            0
# sumamnt_ma_rech90       0
# medianamnt_ma_rech90    0
# medianmarechprebal90    0
# cnt_da_rech30           0
# fr_da_rech30            0
# cnt_da_rech90           0
# fr_da_rech90            0
# cnt_loans30             0
# amnt_loans30            0
# maxamnt_loans30         0
# medianamnt_loans30      0
# cnt_loans90             0
# amnt_loans90            0
# maxamnt_loans90         0
# medianamnt_loans90      0
# payback30               0
# payback90               0
# rental30                0
# rental90                0
# Month                   0
# Day                     0
# dtype: int64

# %%
#Let's plot the heat map for null values

sns.heatmap(credit.isnull(),cmap='Blues')
plt.show()

# %% [markdown]
# We can observe from the above output and heat map that we do not have any null values in our dataset

# %%
#Let's check the statistic matrix

credit.describe().T
# Out:
#                          count          mean           std       min  \
# label                 203119.0      0.883187      0.321198      0.00
# aon                   203119.0   8160.657531  75905.229467      1.00
# daily_decr30          203119.0   5511.941860   9309.431354      0.00
# daily_decr90          203119.0   6231.105509  11027.961422      0.00
# last_rech_date_ma     203119.0   3799.380829  54219.841938      0.00
# last_rech_date_da     203119.0   3752.767072  53650.829181      0.00
# last_rech_amt_ma      203119.0   2085.289825   2376.018149      0.00
# cnt_ma_rech30         203119.0      4.047706      4.283372      0.00
# fr_ma_rech30          203119.0   3776.156209  53944.796311      0.00
# sumamnt_ma_rech30     203119.0   7849.712883  10226.455962      0.00
# medianamnt_ma_rech30  203119.0   1830.622741   2072.939466      0.00
# medianmarechprebal30  203119.0   3844.004978  53952.226750      0.00
# cnt_ma_rech90         203119.0      6.434740      7.241162      0.00
# fr_ma_rech90          203119.0      7.712902     12.474904      0.00
# sumamnt_ma_rech90     203119.0  12648.333839  17004.000431      0.00
# medianamnt_ma_rech90  203119.0   1882.222855   2084.915118      0.00
# medianmarechprebal90  203119.0     94.467030    366.935980      0.00
# cnt_da_rech30         203119.0    265.328927   4208.689338      0.00
# fr_da_rech30          203119.0   3749.316510  53882.074446      0.00
# cnt_da_rech90         203119.0      0.042399      0.402013      0.00
# fr_da_rech90          203119.0      0.047051      0.965935      0.00
# cnt_loans30           203119.0      2.799177      2.573166      0.00
# amnt_loans30          203119.0     18.230230     17.511701      0.00
# maxamnt_loans30       203119.0    274.415764   4244.435327      0.00
# medianamnt_loans30    203119.0      0.054279      0.218531      0.00
# cnt_loans90           203119.0     18.557305    224.834053      0.00
# amnt_loans90          203119.0     24.057572     26.665241      0.00
# maxamnt_loans90       203119.0      6.721587      2.126595      0.00
# medianamnt_loans90    203119.0      0.046099      0.200711      0.00
# payback30             203119.0      3.438569      8.773097      0.00
# payback90             203119.0      4.376189     10.282455      0.00
# rental30              203119.0   2733.769024   4334.881308 -23737.14
# rental90              203119.0   3542.157548   5810.118620 -24720.58
# Day                   203119.0     14.425194      8.430122      1.00
#
#                               25%       50%           75%            max
# label                    1.000000     1.000      1.000000       1.000000
# aon                    250.000000   530.000    983.000000  999860.755168
# daily_decr30            47.631500  1603.126   7448.295000  265926.000000
# daily_decr90            47.906667  1640.000   8048.110000  320630.000000
# last_rech_date_ma        1.000000     3.000      7.000000  998650.377733
# last_rech_date_da        0.000000     0.000      0.000000  999171.809410
# last_rech_amt_ma       770.000000  1539.000   2309.000000   55000.000000
# cnt_ma_rech30            1.000000     3.000      6.000000     203.000000
# fr_ma_rech30             0.000000     2.000      6.000000  999606.368132
# sumamnt_ma_rech30     1546.000000  4717.000  10112.000000  810096.000000
# medianamnt_ma_rech30   770.000000  1539.000   1924.000000   55000.000000
# medianmarechprebal30    12.000000    35.200     84.600000  999479.419319
# cnt_ma_rech90            2.000000     4.000      9.000000     336.000000
# fr_ma_rech90             0.000000     2.000      8.000000      88.000000
# sumamnt_ma_rech90     2486.000000  7695.000  16209.000000  953036.000000
# medianamnt_ma_rech90   773.000000  1539.000   1924.000000   55000.000000
# medianmarechprebal90    15.800000    37.100     80.500000   41456.500000
# cnt_da_rech30            0.000000     0.000      0.000000   99914.441420
# fr_da_rech30             0.000000     0.000      0.000000  999809.240107
# cnt_da_rech90            0.000000     0.000      0.000000      38.000000
# fr_da_rech90             0.000000     0.000      0.000000      64.000000
# cnt_loans30              1.000000     2.000      4.000000      50.000000
# amnt_loans30             6.000000    12.000     24.000000     306.000000
# maxamnt_loans30          6.000000     6.000      6.000000   99864.560864
# medianamnt_loans30       0.000000     0.000      0.000000       3.000000
# cnt_loans90              1.000000     2.000      5.000000    4997.517944
# amnt_loans90             6.000000    12.000     30.000000     438.000000
# maxamnt_loans90          6.000000     6.000      6.000000      12.000000
# medianamnt_loans90       0.000000     0.000      0.000000       3.000000
# payback30                0.000000     1.000      3.833333     171.500000
# payback90                0.000000     1.800      4.571429     171.500000
# rental30               297.065000  1109.580   3421.735000  198926.110000
# rental90               320.130000  1378.160   4286.270000  200148.110000
# Day                      7.000000    14.000     21.000000      31.000000

# %% [markdown]
# #### Observations:
#     1- We can confirm that we do not have any null values in the our dataset.
#
#     2- We can observe that all the features have mean greater than median which means our data is positively skewed.
#
#     3- Most of the features are having outliers.

# %%
#Let's check the correlation with the dependent variable

credit.corr()
credit.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_d331bcf3_7309_11eb_9abb_7440bb6e68e2row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_d331bcf3_7309_11eb_9abb_7440bb6e68e2row0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_d331bcf3_7309_11eb_9abb_7440bb6e68e2row0_col2 {
#             background-color:  #84a7fc;
#             color:  #000000;
#         }    #T_d331bcf3_7309_11eb_9abb_7440bb6e68e2row0_col3 {
#             background-color:  #84a7fc;
#             color:  #000000;
#         }    #T_d331bcf3_7309_11eb_9abb_7440bb6e68e2row0_col4 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_d331bcf3_7309_11eb_9abb_7440bb6e68e2row0_col5 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_d331bcf3_7309_11eb_9abb_7440bb6e68e2row0_col6 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_d331bcf3_7309_11eb_9abb_7440bb6e68e2row0_col7 {
#             background-color:  #aac7fd;
#             color:  #000000;
#         }    #T_d331bcf3_7309_11eb_9abb_7440bb6e68e2row0_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_d331bcf3_7309_11eb_9abb_7440bb6e68e2row0_col9 {
#             background-color:  #8db0fe;
#             color:  #000000;
#         }    #T_d331bcf3_7309_11eb_9abb_7440bb6e68e2row0_col10 {
#             background-color:  #6e90f2;
#             color:  #000000;
#         }    #T_d331bcf3_7309_11eb_9abb_7440bb6e68e2row0_col11 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_d331bcf3_7309_11eb_9abb_7440bb6e68e2row0_col12 {
#             background-color:  #a9c6fd;
#             color:  #000000;
#         }    #T_d331bcf3_7309_11eb_9abb_7440bb6e68e2row0_col13 {
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }    #T_d331bcf3_7309_11eb_9abb_7440bb6e68e2row0_col14 {
#             background-color:  #8caffe;
#             color:  #000000;
#         }    #T_d331bcf3_7309_11eb_9abb_7440bb6e68e2row0_col15 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_d331bcf3_7309_11eb_9abb_7440bb6e68e2row0_col16 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_d331bcf3_7309_11eb_9abb_7440bb6e68e2row0_col17 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_d331bcf3_7309_11eb_9abb_7440bb6e68e2row0_col18 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_d331bcf3_7309_11eb_9abb_7440bb6e68e2row0_col19 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_d331bcf3_7309_11eb_9abb_7440bb6e68e2row0_col20 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_d331bcf3_7309_11eb_9abb_7440bb6e68e2row0_col21 {
#             background-color:  #96b7ff;
#             color:  #000000;
#         }    #T_d331bcf3_7309_11eb_9abb_7440bb6e68e2row0_col22 {
#             background-color:  #97b8ff;
#             color:  #000000;
#         }    #T_d331bcf3_7309_11eb_9abb_7440bb6e68e2row0_col23 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_d331bcf3_7309_11eb_9abb_7440bb6e68e2row0_col24 {
#             background-color:  #6282ea;
#             color:  #000000;
#         }    #T_d331bcf3_7309_11eb_9abb_7440bb6e68e2row0_col25 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_d331bcf3_7309_11eb_9abb_7440bb6e68e2row0_col26 {
#             background-color:  #9abbff;
#             color:  #000000;
#         }    #T_d331bcf3_7309_11eb_9abb_7440bb6e68e2row0_col27 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_d331bcf3_7309_11eb_9abb_7440bb6e68e2row0_col28 {
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }    #T_d331bcf3_7309_11eb_9abb_7440bb6e68e2row0_col29 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_d331bcf3_7309_11eb_9abb_7440bb6e68e2row0_col30 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_d331bcf3_7309_11eb_9abb_7440bb6e68e2row0_col31 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_d331bcf3_7309_11eb_9abb_7440bb6e68e2row0_col32 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_d331bcf3_7309_11eb_9abb_7440bb6e68e2row0_col33 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_d331bcf3_7309_11eb_9abb_7440bb6e68e2row1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_d331bcf3_7309_11eb_9abb_7440bb6e68e2row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_d331bcf3_7309_11eb_9abb_7440bb6e68e2row1_col2 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_d331bcf3_7309_11eb_9abb_7440bb6e68e2row1_col3 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_d331bcf3_7309_11eb_9abb_7440bb6e68e2row1_col4 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_d331bcf3_7309_11eb_9abb_7440bb6e68e2row1_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_d331bcf3_7309_11eb_9abb_7440bb6e68e2row1_col6 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_d331bcf3_7309_11eb_9abb_7440bb6e68e2row1_col7 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_d331bcf3_7309_11eb_9abb_7440bb6e68e2row1_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_d331bcf3_7309_11eb_9abb_7440bb6e68e2row1_col9 {
#             background-color:  #506bda;
#             color:  #000000;
#         }    #T_d331bcf3_7309_11eb_9abb_7440bb6e68e2row1_col10 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_d331bcf3_7309_11eb_9abb_7440bb6e68e2row1_col11 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_d331bcf3_7309_11eb_9abb_7440bb6e68e2row1_col12 {
#             background-color:  #6384eb;
#             color:  #000000;
#         }    #T_d331bcf3_7309_11eb_9abb_7440bb6e68e2row1_col13 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_d331bcf3_7309_11eb_9abb_7440bb6e68e2row1_col14 {
#             background-color:  #4e68d8;
#             color:  #000000;
#         }    #T_d331bcf3_7309_11eb_9abb_7440bb6e68e2row1_col15 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_d331bcf3_7309_11eb_9abb_7440bb6e68e2row1_col16 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_d331bcf3_7309_11eb_9abb_7440bb6e68e2row1_col17 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_d331bcf3_7309_11eb_9abb_7440bb6e68e2row1_col18 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_d331bcf3_7309_11eb_9abb_7440bb6e68e2row1_col19 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_d331bcf3_7309_11eb_9abb_7440bb6e68e2row1_col20 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_d331bcf3_7309_11eb_9abb_7440bb6e68e2row1_col21 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_d331bcf3_7309_11eb_9abb_7440bb6e68e2row1_col22 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_d331bcf3_7309_11eb_9abb_7440bb6e68e2row1_col23 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_d331bcf3_7309_11eb_9abb_7440bb6e68e2row1_col24 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_d331bcf3_7309_11eb_9abb_7440bb6e68e2row1_col25 {
#             background-color:  #

# %%
#Let's plot the heat map for correlation

plt.figure(figsize=(40,35))
#sns.set(font_scale=3.5)
#plt.rcParams.update({'font.size': 38})
sns.heatmap(credit.corr(),annot=True,cmap='coolwarm',annot_kws={"size":12},fmt='0.0%');

# %% [markdown]
# ### Observations:
#
#     1- We can observe that daily_decr30 and daily_decr90 have very high positive correlation with each other.
#
#     2- cnt_loan30 and amnt_loan30 also have very high positive correlation with each other.
#
#     3- We can also obereve that there are many more features which have positive or negative correaltion with eachother.
#
# So we have to drop those columns to avoid multicollinearity

# %%
#Let's drop the columns which are highly correlated with each other inorder to avoid multicolinearity problem

#credit.drop(columns=["daily_decr30","fr_ma_rech30","payback30","rental30","medianamnt_loans30","amnt_loans30",
#                "fr_da_rech30","cnt_da_rech30","sumamnt_ma_rech30","fr_ma_rech30","cnt_ma_rech30"],axis=1, inplace = True)

# %%
#credit.shape

# %% [markdown]
# We have 203119 rows and 25 columns in our dataset post droping correalted columns

# %% [markdown]
# ### Univariate Analysis

# %%
#Lets check the count of each class in target varaible

sns.catplot(x='label',data=credit,kind='count',hue='label')
plt.legend();

# %% [markdown]
# We can observe that our data is imbalanced with a huge numbers. Around 12.5% of the total issued loans were defaulted

# %%
# Let's find out how many values of each class are there

credit['label'].value_counts()
# Out:
# 1    179392
# 0     23727
# Name: label, dtype: int64

# %%
#Let's plot a pie chart for label percentage in dataset

print('Percentage',credit.label.value_counts(normalize=True));
credit.label.value_counts().plot(kind='pie');
# Out:
# Percentage 1    0.883187
# 0    0.116813
# Name: label, dtype: float64

# %%
#Lets plot the countplot of list of features 

list_of_col=['label', 'last_rech_amt_ma','cnt_ma_rech90', 'fr_ma_rech90',
       'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30',
      'amnt_loans90', 'maxamnt_loans90', 'medianamnt_loans90', ]

for i in list_of_col:
    plt.subplots(figsize=(20,8))
    sns.countplot(i,data=credit)
    plt.show()

# %%
plt.figure(figsize=(10,6))
sns.distplot(credit["daily_decr30"],kde=False)
plt.xticks(rotation = 90)
plt.xlabel('Daily amount spent averaged over last 30 days in Rupiah')
plt.ylabel('Number of Users')
plt.title('Distribution of Daily amount spent averaged over last 30 days');

# %%
plt.figure(figsize=(10,6))
sns.distplot(credit["daily_decr90"],kde=False)
plt.xticks(rotation = 90)
plt.xlabel('Daily amount spent averaged over last 90 days in Rupiah')
plt.ylabel('Number of Users')
plt.title('Distribution of Daily amount spent averaged over last 90 days');

# %% [markdown]
# here are many outlier values present in the Daily amount spent averaged over last 30/90 days column i.e. extremely high values, so we will remove them

# %%
plt.figure(figsize=(10,6))
sns.distplot(credit["rental30"],kde=False)
plt.xticks(rotation = 90)
plt.xlabel('Average main account balance over last 30 days in Rupiah')
plt.ylabel('Number of Users')
plt.title('Distribution of Average main account balance over last 30 days');

# %%
plt.figure(figsize=(10,6))
sns.distplot(credit["rental90"],kde=False)
plt.xticks(rotation = 90)
plt.xlabel('Average main account balance over last 90 days')
plt.ylabel('Number of Users')
plt.title('Distribution of Daily amount spent averaged over last 90 days');

# %% [markdown]
# Most of the users have low Average main account balance or very few users have higher balance

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x="label", y="rental30",data=credit)
plt.xlabel('Default Status (0:Defaulter, 1:Non Defaulter)')
plt.ylabel('Average main account balance over last 30 days in Rupiah')
plt.title('Average main account balance over last 30 days in Rupiah vs Default Status - Boxplot')
# Out:
# Text(0.5, 1.0, 'Average main account balance over last 30 days in Rupiah vs Default Status - Boxplot')

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x="label", y="rental90",data=credit)
plt.xlabel('Default Status (0:Defaulter, 1:Non Defaulter)')
plt.ylabel('Average main account balance over last 90 days in Rupiah')
plt.title('Average main account balance over last 90 days in Rupiah vs Default Status - Boxplot');

# %% [markdown]
# From the above plots, Average main account balance over last 30/90 days is relatively lower for the defaulters, this implies that people with higher average main account balance are generally more credible

# %%
plt.figure(figsize=(10,6))
sns.distplot(credit["last_rech_date_ma"],kde=False)
plt.xticks(rotation = 90)
plt.xlabel('Number of days till last recharge of main account')
plt.ylabel('Number of Users')
plt.title('Distribution of Number of days till last recharge of main account');

# %%
plt.figure(figsize=(10,6))
sns.distplot(credit["last_rech_date_da"],kde=False)
plt.xticks(rotation = 90)
plt.xlabel('Number of days till last recharge of data account')
plt.ylabel('Number of Users')
plt.title('Distribution of Number of days till last recharge of data account');

# %% [markdown]
# Number of days till last recharge of main/data account columns contain a lot of garbage values i.e. extremely high float numbers and negative numbers so we will drop them

# %%
plt.figure(figsize=(10,6))
sns.distplot(credit["last_rech_amt_ma"],kde=False)
plt.xticks(rotation = 90)
plt.xlabel('Amount of last recharge of main account (in Indonesian Rupiah)')
plt.ylabel('Number of Users')
plt.title('Distribution of Amount of last recharge of main account');

# %% [markdown]
# Amount of last recharge of main account (in Indonesian Rupiah) contains many outliers, so we will emove all the values over 13000 Rupiah

# %% [markdown]
# ## Bivarient Analysis

# %%
table_medianamnt_loans90  = pd.crosstab(credit['medianamnt_loans90'], credit['label'])
table_medianamnt_loans30 = pd.crosstab(credit['medianamnt_loans30'], credit['label'])
table_maxamnt_loans90  = pd.crosstab(credit['maxamnt_loans90'], credit['label'])

fig = plt.figure(figsize = (17,6))

ax = fig.add_subplot(1,2,1)
(table_medianamnt_loans90.div(table_medianamnt_loans90.sum(axis= 1),axis = 0)*100).sort_values(by= 1).plot(kind = 'bar',ax=ax);
plt.xlabel("Median amt of loan in rupees",fontsize = 14);
plt.ylabel('Count',fontsize = 14);


ax = fig.add_subplot(1,2,2)
(table_medianamnt_loans30.div(table_medianamnt_loans30.sum(axis = 1),axis = 0)*100).sort_values(by = 0).plot(kind = 'bar',ax=ax);
plt.xlabel("Median amt of loan in indonesia rupia",fontsize = 14);
plt.ylabel('Count',fontsize = 14);

# %%
fig = plt.figure(figsize = (17,6))

ax = fig.add_subplot(1,2,2)
(table_maxamnt_loans90.div(table_maxamnt_loans90.sum(axis = 1),axis = 0)*100).sort_values(by = 0).plot(kind = 'bar',ax=ax);
plt.xlabel("Max amt of loan in  rupees",fontsize = 14);
plt.ylabel('Count',fontsize = 14);

# %%
plt.figure(figsize=(12,6))
sns.countplot(x="label",hue="maxamnt_loans90", data = credit)
plt.ylabel('Number of Adults')
plt.xlabel('Default Status (0:Defaulter, 1:Non Defaulter)')
plt.title('Credit default as per maximum amount of loan taken by the user in last 90 days');

# %%
conditions_1=[(credit['rental90'] <=0),credit['rental90'].between(0,1379),credit['rental90'].between(1379,4280),(credit['rental90'] > 4280)]
values_1= ['Negative or zero Balance', 'Low Balance', 'Average Balance','High Balance']
credit['Balance_Category']=np.select(conditions_1,values_1)

# %%
credit['Balance_Category'].value_counts()
# Out:
# Low Balance                 89756
# High Balance                50849
# Average Balance             50681
# Negative or zero Balance    11833
# Name: Balance_Category, dtype: int64

# %%
#Let's Map the balance groups with precentage value with respect to label 

balance_category_percent = pd.crosstab(credit['label'],credit['Balance_Category']).apply(lambda x: x/x.sum()*100)
balance_category_percent = balance_category_percent.transpose()
balance_category_percent
# Out:
# label                             0          1
# Balance_Category
# Average Balance           10.017561  89.982439
# High Balance               7.905760  92.094240
# Low Balance               12.589688  87.410312
# Negative or zero Balance  28.141638  71.858362

# %%
balance_category_percent.plot(kind='bar',color='rgbymck',figsize=(15,5))
plt.title('Average main account balance over last 90 days vs Loan Repayment Percentage within 5 days',fontsize=15)
plt.ylabel('Loan Repayment Percentage within 5 days',fontsize=15)
plt.xlabel('Balance Category',fontsize=15)
plt.xticks(rotation = 'horizontal',fontsize=12);

# %% [markdown]
# ### Observations:
#
#     1- Approx. 30% of Users having negative or zero balance are defaulters, which is very high.
#
#     2- Approx. 10% to 12% Users are defaulters which falls in the category of Average and Low balance category.
#
#     3- Users having high balance and are defaulters are very less in number

# %%
#Let's cehck the number of loans taken by user in last 90 days

conditions_2=[(credit['cnt_loans90'] <=0),credit['cnt_loans90'].between(0,2),(credit['cnt_loans90'] > 2)]
values_2= ['No Loans Taken', 'Average number of loans Taken','Too much loans taken']
credit['Loans_Frequency']=np.select(conditions_2,values_2)

# %%
credit['Loans_Frequency'].value_counts()
# Out:
# Average number of loans Taken    105559
# Too much loans taken              95554
# No Loans Taken                     2006
# Name: Loans_Frequency, dtype: int64

# %%
#Let's Map the balance groups with precentage value with respect to label 

Loans_Frequency_percent = pd.crosstab(credit['label'],credit['Loans_Frequency']).apply(lambda x: x/x.sum()*100)
Loans_Frequency_percent = Loans_Frequency_percent.transpose()
Loans_Frequency_percent
# Out:
# label                                  0           1
# Loans_Frequency
# Average number of loans Taken  19.497153   80.502847
# No Loans Taken                  0.000000  100.000000
# Too much loans taken            3.292379   96.707621

# %%
Loans_Frequency_percent.plot(kind='bar',figsize=(15,5))
plt.title('Number of loans taken by user in last 90 days vs Loan Repayment Percentage within 5 days',fontsize=15)
plt.ylabel('Loan Repayment Percentage within 5 days',fontsize=15)
plt.xlabel('Loans Frequency',fontsize=15)
plt.xticks(rotation = 'horizontal',fontsize=12);

# %% [markdown]
# ### Observations:
#
#     1- Users who take more number of loans are non-defaulters (i.e. 98% of the category) as they repays the loan within the given time i.e. 5 days.
#
#     2- Approx. 14% of the Users are are among the average number of loan taken category are defaulters.

# %%
#Let's check the total amount of recharge in main account over last 90 days (in Indian Rupee)

conditions_3=[(credit['sumamnt_ma_rech90'] <=0),credit['sumamnt_ma_rech90'].between(0,12),credit['sumamnt_ma_rech90'].between(12,15),(credit['sumamnt_ma_rech90'] > 14)]
values_3= ['No Recharge', 'Between 0 and 12(Rupiah)', 'Between 12 and 15(Rupiah)','More than 15']
credit['Recharge_Amount_Category']=np.select(conditions_3,values_3)

# %%
credit['Recharge_Amount_Category'].value_counts()
# Out:
# More than 15    183868
# No Recharge      19251
# Name: Recharge_Amount_Category, dtype: int64

# %%
#Let's map the balance groups with precentage value with respect to label 

Recharge_Amount_Category_percent = pd.crosstab(credit['label'],credit['Recharge_Amount_Category']).apply(lambda x: x/x.sum()*100)
Recharge_Amount_Category_percent = Recharge_Amount_Category_percent.transpose()
Recharge_Amount_Category_percent
# Out:
# label                             0          1
# Recharge_Amount_Category
# More than 15               8.681772  91.318228
# No Recharge               40.330372  59.669628

# %%
Recharge_Amount_Category_percent.plot(kind='bar',color='rgbymck',figsize=(15,5))
plt.title('Total amount of recharge in main account over last 90 days (in Indian Rupee) vs Loan Repayment Percentage within 5 days',fontsize=15)
plt.ylabel('Loan Repayment Percentage within 5 days',fontsize=15)
plt.xlabel('Recharge_Amount_Category',fontsize=15)
plt.xticks(rotation = 'horizontal',fontsize=12);

# %% [markdown]
# ### Observations:
#
#     1- 40 % of the Users who do not even recharged in the 90 days are defaulters only
#
#     2- Users who do very high amount of recharge always pays their loans on time. i.e 98% of them are non-defaulters

# %%
#Let's cehck the Average payback time in days over last 90 days

conditions_4=[(credit['payback90'] <=5),(credit['payback90'] > 5)]
values_4= ['Not Defaulters','Defaulters']
credit['Defaulters_Category']=np.select(conditions_4,values_4)

# %%
credit['Defaulters_Category'].value_counts()
# Out:
# Not Defaulters    158091
# Defaulters         45028
# Name: Defaulters_Category, dtype: int64

# %%
#Let's ,ap the balance groups with precentage value with respect to label 

Defaulters_Category_percent = pd.crosstab(credit['label'],credit['Defaulters_Category']).apply(lambda x: x/x.sum()*100)
Defaulters_Category_percent = Defaulters_Category_percent.transpose()
Defaulters_Category_percent
# Out:
# label                        0          1
# Defaulters_Category
# Defaulters            6.955672  93.044328
# Not Defaulters       13.027307  86.972693

# %%
Defaulters_Category_percent.plot(kind='bar',figsize=(15,5))
plt.title('Average payback time in days over last 90 days vs Loan Repayment Percentage within 5 days',fontsize=15)
plt.ylabel('Loan Repayment Percentage within 5 days',fontsize=15)
plt.xlabel('Defaulters_Category',fontsize=15)
plt.xticks(rotation = 'horizontal',fontsize=12);

# %%
#Let's check the total amount of loans taken by user in last 90 days

conditions_5=[(credit['amnt_loans90'] <=0),credit['amnt_loans90'].between(0,1),credit['amnt_loans90'].between(1,3),(credit['amnt_loans90'] > 3)]
values_5= ['No loans', 'Low Amount', 'Average Amount','High Amount']
credit['Loan_Amount_Category']=np.select(conditions_5,values_5)

# %%
credit['Loan_Amount_Category'].value_counts()
# Out:
# High Amount    201106
# No loans         2013
# Name: Loan_Amount_Category, dtype: int64

# %%
#Let's map the balance groups with precentage value with respect to label 

Loan_Amount_Category_percent = pd.crosstab(credit['label'],credit['Loan_Amount_Category']).apply(lambda x: x/x.sum()*100)
Loan_Amount_Category_percent = Loan_Amount_Category_percent.transpose()
Loan_Amount_Category_percent
# Out:
# label                         0           1
# Loan_Amount_Category
# High Amount           11.798256   88.201744
# No loans               0.000000  100.000000

# %%
Loan_Amount_Category_percent.plot(kind='bar',color='rgbymck',figsize=(15,5))
plt.title('Total amount of loans taken by user in last 90 days vs Loan Repayment Percentage within 5 days',fontsize=15)
plt.ylabel('Loan Repayment Percentage within 5 days',fontsize=15)
plt.xlabel('Loan Amount Category',fontsize=15)
plt.xticks(rotation = 'horizontal',fontsize=12);

# %% [markdown]
# ### Observations:
#
#     1- Users who did not take any loans are non-defaulters
#
#     2- Most of the Users (i.e. 88%) who take large amount of loans comes under non defaulter category

# %%
# Let's check the number of times main account got recharged in last 90 days

conditions_6=[(credit['cnt_ma_rech90'] <=0),credit['cnt_ma_rech90'].between(0,1),credit['cnt_ma_rech90'].between(1,3),(credit['cnt_ma_rech90'] > 3)]
values_6= ['Not Recharged', 'Low Recharge Frequency', 'Average Recharge Frequency','High Recharge Frequency']
credit['Recharge Frequency']=np.select(conditions_6,values_6)

# %%
credit['Recharge Frequency'].value_counts()
# Out:
# High Recharge Frequency       114891
# Average Recharge Frequency     42910
# Low Recharge Frequency         26067
# Not Recharged                  19251
# Name: Recharge Frequency, dtype: int64

# %%
#Let's maap the balance groups with precentage value with respect to label 

Recharge_Frequency_percent = pd.crosstab(credit['label'],credit['Recharge Frequency']).apply(lambda x: x/x.sum()*100)
Recharge_Frequency_percent = Recharge_Frequency_percent.transpose()
Recharge_Frequency_percent
# Out:
# label                               0          1
# Recharge Frequency
# Average Recharge Frequency  12.465626  87.534374
# High Recharge Frequency      3.342298  96.657702
# Low Recharge Frequency      25.986880  74.013120
# Not Recharged               40.330372  59.669628

# %%
Recharge_Frequency_percent.plot(kind='bar',figsize=(15,5))
plt.title('Number of times main account got recharged in last 90 days vs Loan Repayment Percentage within 5 days',fontsize=15)
plt.ylabel('Loan Repayment Percentage within 5 days',fontsize=15)
plt.xlabel('Recharge Frequency',fontsize=15)
plt.xticks(rotation = 'horizontal',fontsize=12);

# %% [markdown]
# ### Observations:
#
#     1- Among the Users who have not done a single recharge in 3 months 40% are defaulters
#
#     2- Among the Users who are very frequent in recharging and who always pay their loans on time are more in number i.e 96% of the total category, which is a good news for the company

# %%
#Let's check the moble number users aon

conditions_7=[(credit['aon'] <2),credit['aon'].between(2,5),(credit['aon'] > 5)]
values_7= ['New Users','Average Users','Old Users']
credit['Users_Category']=np.select(conditions_7,values_7)

# %%
credit['Users_Category'].value_counts()
# Out:
# Old Users        203013
# New Users            96
# Average Users        10
# Name: Users_Category, dtype: int64

# %%
#Let's map the balance groups with precentage value with respect to label 

Users_Category_percent = pd.crosstab(credit['label'],credit['Users_Category']).apply(lambda x: x/x.sum()*100)
Users_Category_percent = Users_Category_percent.transpose()
Users_Category_percent
# Out:
# label                   0           1
# Users_Category
# Average Users    0.000000  100.000000
# New Users       35.416667   64.583333
# Old Users       11.670681   88.329319

# %%
Users_Category_percent.plot(kind='bar',color='rgbymck',figsize=(15,5))
plt.title('age on cellular network in days vs Loan Repayment Percentage within 5 days',fontsize=15)
plt.ylabel('Loan Repayment Percentage within 5 days',fontsize=15)
plt.xlabel('Users Category',fontsize=15)
plt.xticks(rotation = 'horizontal',fontsize=12);

# %% [markdown]
# ### Observations:
#
#     1- 35% of the users who are defaulters are the new users
#
#     2- Old Users are trusted and they are mostly non defaulters

# %%
#Let's plot the histogram

credit.hist(figsize=(20,20),layout=(8,5));

# %% [markdown]
# We can observe that most of the dat is positively skewed
